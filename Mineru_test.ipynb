# %%
# !pip install -U "mineru[all]"
# Out:
# Requirement already satisfied: mineru[all] in /usr/local/lib/python3.12/dist-packages (2.7.6)
# Requirement already satisfied: boto3>=1.28.43 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (1.42.73)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (8.3.1)
# Requirement already satisfied: loguru>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.7.3)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (2.0.2)
# Requirement already satisfied: pdfminer.six>=20251230 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (20260107)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (4.67.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (2.32.4)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.28.1)
# Requirement already satisfied: pillow>=11.0.0 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (11.3.0)
# Requirement already satisfied: pypdfium2>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (4.30.0)
# Requirement already satisfied: pypdf>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (6.9.1)
# Requirement already satisfied: reportlab in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (4.4.10)
# Requirement already satisfied: pdftext>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.6.3)
# Requirement already satisfied: modelscope>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (1.35.1)
# Requirement already satisfied: huggingface-hub>=0.32.4 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.36.2)
# Requirement already satisfied: json-repair>=0.46.2 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.58.6)
# Requirement already satisfied: opencv-python>=4.11.0.86 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (4.13.0.92)
# Requirement already satisfied: fast-langdetect<0.3.0,>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.2.5)
# Requirement already satisfied: scikit-image<1.0.0,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.25.2)
# Requirement already satisfied: openai<3,>=1.70.0 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (2.28.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.13.5 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (4.13.5)
# Requirement already satisfied: magika<1.1.0,>=0.6.2 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (1.0.2)
# Requirement already satisfied: mineru-vl-utils<1,>=0.1.19.1 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.1.22)
# Requirement already satisfied: qwen-vl-utils<1,>=0.0.14 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.0.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=4.13.5->mineru[all]) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5,>=4.13.5->mineru[all]) (4.15.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.73 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.43->mineru[all]) (1.42.73)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.43->mineru[all]) (1.1.0)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3>=1.28.43->mineru[all]) (0.16.0)
# Requirement already satisfied: robust-downloader>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fast-langdetect<0.3.0,>=0.2.3->mineru[all]) (0.0.2)
# Requirement already satisfied: fasttext-predict>=0.9.2.4 in /usr/local/lib/python3.12/dist-packages (from fast-langdetect<0.3.0,>=0.2.3->mineru[all]) (0.9.2.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.32.4->mineru[all]) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.32.4->mineru[all]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.32.4->mineru[all]) (1.4.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.32.4->mineru[all]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.32.4->mineru[all]) (6.0.3)
# Requirement already satisfied: onnxruntime>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from magika<1.1.0,>=0.6.2->mineru[all]) (1.24.4)
# Requirement already satisfied: httpx-retries in /usr/local/lib/python3.12/dist-packages (from mineru-vl-utils<1,>=0.1.19.1->mineru[all]) (0.4.6)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from mineru-vl-utils<1,>=0.1.19.1->mineru[all]) (24.1.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from mineru-vl-utils<1,>=0.1.19.1->mineru[all]) (2.11.10)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from modelscope>=1.26.0->mineru[all]) (79.0.1)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.12/dist-packages (from modelscope>=1.26.0->mineru[all]) (2.5.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<3,>=1.70.0->mineru[all]) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3,>=1.70.0->mineru[all]) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3,>=1.70.0->mineru[all]) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3,>=1.70.0->mineru[all]) (1.3.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->mineru[all]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->mineru[all]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->mineru[all]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->mineru[all]) (0.16.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six>=20251230->mineru[all]) (3.4.6)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six>=20251230->mineru[all]) (43.0.3)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.2.1 in /usr/local/lib/python3.12/dist-packages (from pdftext>=0.6.3->mineru[all]) (2.13.1)
# Requirement already satisfied: av in /usr/local/lib/python3.12/dist-packages (from qwen-vl-utils<1,>=0.0.14->mineru[all]) (17.0.0)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[all]) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[all]) (3.6.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[all]) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[all]) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image<1.0.0,>=0.25.0->mineru[all]) (0.5)
# Requirement already satisfied: vllm<0.12,>=0.10.1.1 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.11.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.73->boto3>=1.28.43->mineru[all]) (2.9.0.post0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six>=20251230->mineru[all]) (2.0.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.17.0->magika<1.1.0,>=0.6.2->mineru[all]) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.17.0->magika<1.1.0,>=0.6.2->mineru[all]) (5.29.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.17.0->magika<1.1.0,>=0.6.2->mineru[all]) (1.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->mineru-vl-utils<1,>=0.1.19.1->mineru[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->mineru-vl-utils<1,>=0.1.19.1->mineru[all]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->mineru-vl-utils<1,>=0.1.19.1->mineru[all]) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.2.1->pdftext>=0.6.3->mineru[all]) (1.2.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from robust-downloader>=0.0.2->fast-langdetect<0.3.0,>=0.2.3->mineru[all]) (6.10.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (2025.11.3)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (6.2.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.2.1)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (1.0.8)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (9.0.0)
# Requirement already satisfied: transformers>=4.55.2 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (4.57.6)
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.22.2)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.135.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (3.13.3)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.24.1)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.12.0)
# Requirement already satisfied: lm-format-enforcer==0.11.3 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.11.3)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.11 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.7.30)
# Requirement already satisfied: outlines_core==0.2.11 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.2.11)
# Requirement already satisfied: diskcache==5.6.3 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (5.6.3)
# Requirement already satisfied: lark==1.2.2 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (1.2.2)
# Requirement already satisfied: xgrammar==0.1.25 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.1.25)
# Requirement already satisfied: partial-json-parser in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.2.1.1.post7)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (26.2.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.20.0)
# Requirement already satisfied: gguf>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.18.0)
# Requirement already satisfied: mistral_common>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from mistral_common[audio,image]>=1.8.2->vllm<0.12,>=0.10.1.1->mineru[all]) (1.10.0)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (4.13.0.92)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (1.17.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.8.2)
# Requirement already satisfied: compressed-tensors==0.11.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.11.0)
# Requirement already satisfied: depyf==0.19.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.19.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (3.1.2)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (1.1.1)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (4.0.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (1.13.0)
# Requirement already satisfied: pybase64 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (1.4.3)
# Requirement already satisfied: cbor2 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (5.8.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (1.3.7)
# Requirement already satisfied: openai-harmony>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.0.8)
# Requirement already satisfied: numba==0.61.2 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.61.2)
# Requirement already satisfied: ray>=2.48.0 in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm<0.12,>=0.10.1.1->mineru[all]) (2.54.0)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (2.8.0)
# Requirement already satisfied: torchaudio==2.8.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (2.8.0)
# Requirement already satisfied: torchvision==0.23.0 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.23.0)
# Requirement already satisfied: xformers==0.0.32.post1 in /usr/local/lib/python3.12/dist-packages (from vllm<0.12,>=0.10.1.1->mineru[all]) (0.0.32.post1)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from compressed-tensors==0.11.0->vllm<0.12,>=0.10.1.1->mineru[all]) (2.4.7)
# Requirement already satisfied: astor in /usr/local/lib/python3.12/dist-packages (from depyf==0.19.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from depyf==0.19.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.3.8)
# Requirement already satisfied: interegular>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from lm-format-enforcer==0.11.3->vllm<0.12,>=0.10.1.1->mineru[all]) (0.3.3)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba==0.61.2->vllm<0.12,>=0.10.1.1->mineru[all]) (0.44.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm<0.12,>=0.10.1.1->mineru[all]) (3.4.0)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.0.22)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.42.0)
# Requirement already satisfied: gradio==5.49.1 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (5.49.1)
# Requirement already satisfied: gradio-pdf==0.0.22 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.0.22)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (1.2.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (1.0.0)
# Requirement already satisfied: gradio-client==1.13.3 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (1.13.3)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (0.1.2)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (3.11.7)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (2.2.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (0.25.1)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (0.15.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio==5.49.1->mineru[all]) (0.24.1)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio-client==1.13.3->gradio==5.49.1->mineru[all]) (15.0.1)
# Requirement already satisfied: matplotlib<4,>=3.10 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (3.10.0)
# Requirement already satisfied: ultralytics<9,>=8.3.48 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (8.4.24)
# Requirement already satisfied: doclayout_yolo==0.0.4 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (0.0.4)
# Requirement already satisfied: ftfy<7,>=6.3.1 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (6.3.1)
# Requirement already satisfied: shapely<3,>=2.0.7 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (2.1.2)
# Requirement already satisfied: pyclipper<2,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (1.4.0)
# Requirement already satisfied: omegaconf<3,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (2.3.0)
# Requirement already satisfied: thop>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from doclayout_yolo==0.0.4->mineru[all]) (0.1.1.post2209072238)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from doclayout_yolo==0.0.4->mineru[all]) (0.13.2)
# Requirement already satisfied: albumentations>=1.4.11 in /usr/local/lib/python3.12/dist-packages (from doclayout_yolo==0.0.4->mineru[all]) (2.0.8)
# Requirement already satisfied: accelerate>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from mineru[all]) (1.13.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.5.1->mineru[all]) (0.7.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six>=20251230->mineru[all]) (3.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.0.4)
# Requirement already satisfied: fastapi-cli>=0.0.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.0.24)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (2.3.0)
# Requirement already satisfied: pydantic-extra-types>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (2.11.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy<7,>=6.3.1->mineru[all]) (0.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[all]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[all]) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib<4,>=3.10->mineru[all]) (3.3.2)
# Requirement already satisfied: jsonschema>=4.21.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<0.12,>=0.10.1.1->mineru[all]) (4.26.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf<3,>=2.3.0->mineru[all]) (4.9.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm<0.12,>=0.10.1.1->mineru[all]) (1.1.2)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm<0.12,>=0.10.1.1->mineru[all]) (14.0.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->onnxruntime>=1.17.0->magika<1.1.0,>=0.6.2->mineru[all]) (1.3.0)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics<9,>=8.3.48->mineru[all]) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /usr/local/lib/python3.12/dist-packages (from ultralytics<9,>=8.3.48->mineru[all]) (2.0.18)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<0.12,>=0.10.1.1->mineru[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<0.12,>=0.10.1.1->mineru[all]) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<0.12,>=0.10.1.1->mineru[all]) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<0.12,>=0.10.1.1->mineru[all]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<0.12,>=0.10.1.1->mineru[all]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<0.12,>=0.10.1.1->mineru[all]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm<0.12,>=0.10.1.1->mineru[all]) (1.23.0)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru[all]) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru[all]) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout_yolo==0.0.4->mineru[all]) (6.5.16)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (2.8.0)
# Requirement already satisfied: rich-toolkit>=0.14.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.19.7)
# Requirement already satisfied: fastapi-cloud-cli>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.15.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<0.12,>=0.10.1.1->mineru[all]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<0.12,>=0.10.1.1->mineru[all]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<0.12,>=0.10.1.1->mineru[all]) (0.30.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.49.1->mineru[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0,>=1.0->gradio==5.49.1->mineru[all]) (2025.3)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics<9,>=8.3.48->mineru[all]) (1.35.2)
# Requirement already satisfied: pycountry>=23 in /usr/local/lib/python3.12/dist-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<0.12,>=0.10.1.1->mineru[all]) (26.2.16)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.49.1->mineru[all]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio==5.49.1->mineru[all]) (13.9.4)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.22.1)
# Requirement already satisfied: cuda-pathfinder==1.*,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x->ray[cgraph]>=2.48.0->vllm<0.12,>=0.10.1.1->mineru[all]) (1.4.3)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<0.12,>=0.10.1.1->mineru[all]) (0.13.1)
# Requirement already satisfied: soxr>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm<0.12,>=0.10.1.1->mineru[all]) (1.0.0)
# Requirement already satisfied: rignore>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.7.6)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (2.54.0)
# Requirement already satisfied: fastar>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm<0.12,>=0.10.1.1->mineru[all]) (0.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1->mineru[all]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1->mineru[all]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio==5.49.1->mineru[all]) (0.1.2)

# %%
# !wget https://arxiv.org/pdf/2501.17887
# Out:
# --2026-03-22 06:59:22--  https://arxiv.org/pdf/2501.17887
# Resolving arxiv.org (arxiv.org)... 151.101.195.42, 151.101.67.42, 151.101.131.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.195.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 589880 (576K) [application/pdf]
# Saving to: ‘2501.17887’
#
# 2501.17887          100%[===================>] 576.05K  --.-KB/s    in 0.03s
#
# 2026-03-22 06:59:22 (21.6 MB/s) - ‘2501.17887’ saved [589880/589880]

# %%
# !mineru -p /content/250117887.pdf -o .
# Out:
# 2026-03-22 06:59:42.526 | INFO     | mineru.utils.engine_utils:get_vlm_engine:32 - Using vllm-engine as the inference engine for VLM.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Fetching 14 files:   0% 0/14 [00:00<?, ?it/s]
# added_tokens.json: 100% 800/800 [00:00<00:00, 5.66MB/s]
#
# README.md: 0.00B [00:00, ?B/s]
#
# .gitattributes: 0.00B [00:00, ?B/s]
# chat_template.json: 0.00B [00:00, ?B/s]
#
#
# README.md: 17.4kB [00:00, 433kB/s]
# .gitattributes: 1.52kB [00:00, 302kB/s]
# chat_template.json: 1.05kB [00:00, 66.2kB/s]
# generation_config.json: 100% 272/272 [00:00<00:00, 19.9kB/s]
#
# merges.txt: 1.67MB [00:00, 52.0MB/s]
#
# config.json: 1.19kB [00:00, 7.81MB/s]
#
# model.safetensors:   0% 0.00/2.31G [00:00<?, ?B/s]
#
# tokenizer.json: 0.00B [00:00, ?B/s]
#
#
# special_tokens_map.json: 4.70kB [00:00, 18.6MB/s]
#
#
#
# video_preprocessor_config.json: 100% 346/346 [00:00<00:00, 3.09MB/s]
#
#
#
# tokenizer_config.json: 9.09kB [00:00, 52.3MB/s]
#
#
#
# vocab.json: 2.78MB [00:00, 97.9MB/s]
# tokenizer.json: 7.03MB [00:00, 94.0MB/s]
#
# model.safetensors:   0% 0.00/2.31G [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/2.31G [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/2.31G [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/2.31G [00:00<?, ?B/s]
# model.safetensors:   0% 0.00/2.31G [00:01<?, ?B/s]
# model.safetensors:   0% 0.00/2.31G [00:01<?, ?B/s]
# model.safetensors:   3% 77.1M/2.31G [00:01<00:06, 367MB/s]
# model.safetensors:  11% 256M/2.31G [00:02<00:13, 150MB/s]
# model.safetensors:  13% 310M/2.31G [00:03<00:18, 110MB/s]
# model.safetensors:  20% 464M/2.31G [00:05<00:15, 116MB/s]
# model.safetensors:  23% 541M/2.31G [00:06<00:21, 83.2MB/s]
# model.safetensors:  33% 771M/2.31G [00:16<00:44, 34.9MB/s]
# model.safetensors:  37% 848M/2.31G [00:16<00:33, 43.2MB/s]
# model.safetensors:  50% 1.16G/2.31G [00:18<00:16, 71.2MB/s]
# model.safetensors: 100% 2.31G/2.31G [00:22<00:00, 101MB/s]
# Fetching 14 files: 100% 14/14 [00:23<00:00,  1.66s/it]
# 2026-03-22 07:00:08.871 | INFO     | mineru.backend.vlm.utils:enable_custom_logits_processors:49 - compute_capability: 7.5 < 8.0, but vllm version: 0.11.0 >= 0.10.2, enable custom_logits_processors
# INFO 03-22 07:00:10 [__init__.py:216] Automatically detected platform cuda.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774162812.764628    3274 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774162812.822935    3274 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774162813.223590    3274 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774162813.223627    3274 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774162813.223634    3274 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774162813.223639    3274 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# INFO 03-22 07:00:23 [utils.py:233] non-default args: {'gpu_memory_utilization': 0.5, 'disable_log_stats': True, 'logits_processors': [<class 'mineru_vl_utils.logits_processor.vllm_v1_no_repeat_ngram.VllmV1NoRepeatNGramLogitsProcessor'>], 'model': '/root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67'}
# INFO 03-22 07:00:47 [model.py:547] Resolved architecture: Qwen2VLForConditionalGeneration
# `torch_dtype` is deprecated! Use `dtype` instead!
# WARNING 03-22 07:00:47 [model.py:1682] Your device 'Tesla T4' (with compute capability 7.5) doesn't support torch.bfloat16. Falling back to torch.float16 for compatibility.
# WARNING 03-22 07:00:47 [model.py:1733] Casting torch.bfloat16 to torch.float16.
# INFO 03-22 07:00:47 [model.py:1510] Using max model len 16384
# INFO 03-22 07:00:47 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 03-22 07:00:49 [__init__.py:3036] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reasons: CUDA is initialized
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774162855.232572    3622 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774162855.239664    3622 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774162855.259420    3622 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774162855.259445    3622 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774162855.259451    3622 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774162855.259454    3622 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# INFO 03-22 07:01:01 [__init__.py:216] Automatically detected platform cuda.
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:02 [core.py:644] Waiting for init message from front-end.
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:02 [core.py:77] Initializing a V1 LLM engine (v0.11.0) with config: model='/root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67', speculative_config=None, tokenizer='/root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=16384, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=/root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67, enable_prefix_caching=True, chunked_prefill_enabled=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention","vllm.sparse_attn_indexer"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":[2,1],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"use_inductor_graph_partition":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=3622) ERROR 03-22 07:01:06 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:07 [parallel_state.py:1208] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (EngineCore_DP0 pid=3622) WARNING 03-22 07:01:07 [topk_topp_sampler.py:66] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:11 [gpu_model_runner.py:2602] Starting to load model /root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67...
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:12 [gpu_model_runner.py:2634] Loading model from scratch...
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:12 [cuda.py:372] Using FlexAttention backend on V1 engine.
# Loading safetensors checkpoint shards: 100% 1/1 [00:05<00:00,  5.29s/it]
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:18 [default_loader.py:267] Loading weights took 5.35 seconds
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:19 [gpu_model_runner.py:2653] Model loading took 2.1639 GiB and 5.707360 seconds
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:19 [gpu_model_runner.py:3344] Encoder cache will be initialized with a budget of 14175 tokens, and profiled with 1 video items of the maximum feature size.
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:44 [backends.py:548] Using cache directory: /root/.cache/vllm/torch_compile_cache/d288019e11/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:44 [backends.py:559] Dynamo bytecode transform time: 6.05 s
# (EngineCore_DP0 pid=3622) INFO 03-22 07:01:47 [backends.py:197] Cache the graph for dynamic shape for later use
# (EngineCore_DP0 pid=3622) [rank0]:W0322 07:01:48.328000 3622 torch/_inductor/utils.py:1436] [0/0] Not enough SMs to use max_autotune_gemm mode
# (EngineCore_DP0 pid=3622) INFO 03-22 07:02:08 [backends.py:218] Compiling a graph for dynamic shape takes 23.80 s
# (EngineCore_DP0 pid=3622) INFO 03-22 07:02:11 [monitor.py:34] torch.compile takes 29.84 s in total
# (EngineCore_DP0 pid=3622) INFO 03-22 07:02:13 [gpu_worker.py:298] Available KV cache memory: 2.17 GiB
# (EngineCore_DP0 pid=3622) INFO 03-22 07:02:14 [kv_cache_utils.py:1087] GPU KV cache size: 189,824 tokens
# (EngineCore_DP0 pid=3622) INFO 03-22 07:02:14 [kv_cache_utils.py:1091] Maximum concurrency for 16,384 tokens per request: 11.59x
# (EngineCore_DP0 pid=3622) WARNING 03-22 07:02:14 [gpu_model_runner.py:3663] CUDAGraphMode.FULL_AND_PIECEWISE is not supported with FlexAttentionMetadataBuilder backend (support: AttentionCGSupport.NEVER); setting cudagraph_mode=PIECEWISE because attention is compiled piecewise
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100% 67/67 [00:03<00:00, 19.33it/s]
# (EngineCore_DP0 pid=3622) INFO 03-22 07:02:19 [gpu_model_runner.py:3480] Graph capturing finished in 5 secs, took 0.37 GiB
# (EngineCore_DP0 pid=3622) INFO 03-22 07:02:19 [core.py:210] init engine (profile, create kv cache, warmup model) took 60.17 seconds
# INFO 03-22 07:02:20 [llm.py:306] Supported_tasks: ['generate']
# 2026-03-22 07:02:20.523 | INFO     | mineru.backend.vlm.vlm_analyze:get_model:218 - get vllm-engine predictor cost: 154.97s
# 2026-03-22 07:02:22.919 | INFO     | mineru.backend.hybrid.hybrid_analyze:get_batch_ratio:365 - hybrid batch ratio (auto, vram=15GB): 4
# Adding requests: 100% 8/8 [00:04<00:00,  1.96it/s]
# Processed prompts: 100% 8/8 [01:25<00:00, 10.69s/it, est. speed input: 130.41 toks/s, output: 40.87 toks/s]
# Adding requests: 100% 2/2 [00:00<00:00, 57.89it/s]
# Processed prompts: 100% 2/2 [00:10<00:00,  5.27s/it, est. speed input: 33.94 toks/s, output: 12.33 toks/s]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…):   0% 0.00/14.5M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…):   0% 0.00/14.5M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…):   0% 0.00/14.5M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…):   0% 0.00/14.5M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…):  18% 2.58M/14.5M [00:00<00:00, 12.9MB/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…):  73% 10.6M/14.5M [00:01<00:00, 29.0MB/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv5_d(…): 100% 14.5M/14.5M [00:01<00:00, 11.9MB/s]
# Fetching 1 files: 100% 1/1 [00:01<00:00,  1.43s/it]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…):   0% 0.00/101M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…):   0% 0.00/101M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…):   0% 0.00/101M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…):   0% 0.00/101M [00:00<?, ?B/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…):  66% 67.0M/101M [00:00<00:00, 334MB/s]
# models/OCR/paddleocr_torch/ch_PP-OCRv4_r(…): 100% 101M/101M [00:02<00:00, 45.7MB/s]
# Fetching 1 files: 100% 1/1 [00:02<00:00,  2.39s/it]
# Fetching 1 files:   0% 0/1 [00:00<?, ?it/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:00<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:00<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:00<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:00<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:00<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:01<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:01<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:01<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:01<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:01<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt:   0% 0.00/350M [00:02<?, ?B/s]
# models/MFD/YOLO/yolo_v8_ft.pt: 100% 350M/350M [00:02<00:00, 158MB/s]
# Fetching 1 files: 100% 1/1 [00:02<00:00,  2.43s/it]
# Fetching 7 files:   0% 0/7 [00:00<?, ?it/s]
# README.md: 1.66kB [00:00, 742kB/s]
#
# tokenizer_config.json: 4.52kB [00:00, 17.8MB/s]
#
# generation_config.json: 100% 191/191 [00:00<00:00, 1.70MB/s]
#
# tokenizer.json: 0.00B [00:00, ?B/s]
#
# config.json: 0.00B [00:00, ?B/s]
#
#
# special_tokens_map.json: 100% 552/552 [00:00<00:00, 2.93MB/s]
# config.json: 5.09kB [00:00, 4.34MB/s]
# tokenizer.json: 3.58MB [00:00, 101MB/s]
#
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:00<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:00<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:00<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:00<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:00<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:01<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:01<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:01<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:01<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:01<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:02<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:02<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:02<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:02<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:02<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:03<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:03<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:03<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:04<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:04<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:04<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:04<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:05<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:05<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:05<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:05<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:05<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:06<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:06<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:06<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:06<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:06<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:07<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:07<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:07<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:07<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:07<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:08<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:08<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:08<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:08<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:08<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:09<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:09<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:09<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:09<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:09<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:10<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:10<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:10<?, ?B/s]
# Fetching 7 files:  29% 2/7 [00:10<00:00, 14.55it/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:10<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:11<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:11<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:11<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:11<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:11<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:12<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:12<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:12<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:12<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:12<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:13<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:13<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:13<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:13<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:13<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:14<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:14<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:14<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:14<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:14<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:15<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:15<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:15<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:15<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:15<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…):   0% 0.00/810M [00:16<?, ?B/s]
# models/MFR/unimernet_hf_small_2503/model(…): 100% 810M/810M [00:16<00:00, 50.0MB/s]
# Fetching 7 files: 100% 7/7 [00:16<00:00,  2.34s/it]
# MFD Predict: 100% 8/8 [00:03<00:00,  2.54it/s]
# MFR Predict: 100% 26/26 [00:06<00:00,  4.32it/s]
# OCR-det: 100% 8/8 [00:03<00:00,  2.16it/s]
# 2026-03-22 07:04:47.375 | INFO     | mineru.cli.common:_process_output:168 - local output dir is ./250117887/hybrid_auto
# ERROR 03-22 07:04:49 [core_client.py:564] Engine core proc EngineCore_DP0 died unexpectedly, shutting down client.

# %%
# !wget https://arxiv.org/pdf/1706.03762
# !mkdir docs
# !mv 1706.03762 docs/attention_is_all_you_need.pdf
# Out:
# --2026-03-22 07:05:56--  https://arxiv.org/pdf/1706.03762
# Resolving arxiv.org (arxiv.org)... 151.101.67.42, 151.101.195.42, 151.101.3.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.67.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2215244 (2.1M) [application/pdf]
# Saving to: ‘1706.03762’
#
# 1706.03762          100%[===================>]   2.11M  --.-KB/s    in 0.05s
#
# 2026-03-22 07:05:56 (44.0 MB/s) - ‘1706.03762’ saved [2215244/2215244]

# %%
# !mineru -p docs/attention_is_all_you_need.pdf -o .
# Out:
# 2026-03-22 07:06:08.109 | INFO     | mineru.utils.engine_utils:get_vlm_engine:32 - Using vllm-engine as the inference engine for VLM.
# Fetching 14 files: 100% 14/14 [00:00<00:00, 154121.41it/s]
# 2026-03-22 07:06:10.089 | INFO     | mineru.backend.vlm.utils:enable_custom_logits_processors:49 - compute_capability: 7.5 < 8.0, but vllm version: 0.11.0 >= 0.10.2, enable custom_logits_processors
# INFO 03-22 07:06:10 [__init__.py:216] Automatically detected platform cuda.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774163171.761388    5946 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774163171.770205    5946 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774163171.786453    5946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774163171.786478    5946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774163171.786482    5946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774163171.786486    5946 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# INFO 03-22 07:06:19 [utils.py:233] non-default args: {'gpu_memory_utilization': 0.5, 'disable_log_stats': True, 'logits_processors': [<class 'mineru_vl_utils.logits_processor.vllm_v1_no_repeat_ngram.VllmV1NoRepeatNGramLogitsProcessor'>], 'model': '/root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67'}
# INFO 03-22 07:06:19 [model.py:547] Resolved architecture: Qwen2VLForConditionalGeneration
# `torch_dtype` is deprecated! Use `dtype` instead!
# WARNING 03-22 07:06:19 [model.py:1682] Your device 'Tesla T4' (with compute capability 7.5) doesn't support torch.bfloat16. Falling back to torch.float16 for compatibility.
# WARNING 03-22 07:06:19 [model.py:1733] Casting torch.bfloat16 to torch.float16.
# INFO 03-22 07:06:19 [model.py:1510] Using max model len 16384
# INFO 03-22 07:06:21 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 03-22 07:06:24 [__init__.py:3036] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reasons: CUDA is initialized
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774163191.096080    6060 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774163191.103069    6060 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774163191.120448    6060 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774163191.120477    6060 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774163191.120480    6060 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774163191.120483    6060 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# INFO 03-22 07:06:36 [__init__.py:216] Automatically detected platform cuda.
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:37 [core.py:644] Waiting for init message from front-end.
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:37 [core.py:77] Initializing a V1 LLM engine (v0.11.0) with config: model='/root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67', speculative_config=None, tokenizer='/root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=16384, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=/root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67, enable_prefix_caching=True, chunked_prefill_enabled=True, pooler_config=None, compilation_config={"level":3,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":["vllm.unified_attention","vllm.unified_attention_with_output","vllm.mamba_mixer2","vllm.mamba_mixer","vllm.short_conv","vllm.linear_attention","vllm.plamo2_mamba_mixer","vllm.gdn_attention","vllm.sparse_attn_indexer"],"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":[2,1],"use_cudagraph":true,"cudagraph_num_of_warmups":1,"cudagraph_capture_sizes":[512,504,496,488,480,472,464,456,448,440,432,424,416,408,400,392,384,376,368,360,352,344,336,328,320,312,304,296,288,280,272,264,256,248,240,232,224,216,208,200,192,184,176,168,160,152,144,136,128,120,112,104,96,88,80,72,64,56,48,40,32,24,16,8,4,2,1],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"use_inductor_graph_partition":false,"pass_config":{},"max_capture_size":512,"local_cache_dir":null}
# (EngineCore_DP0 pid=6060) ERROR 03-22 07:06:42 [fa_utils.py:57] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:42 [parallel_state.py:1208] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# (EngineCore_DP0 pid=6060) WARNING 03-22 07:06:43 [topk_topp_sampler.py:66] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:46 [gpu_model_runner.py:2602] Starting to load model /root/.cache/huggingface/hub/models--opendatalab--MinerU2.5-2509-1.2B/snapshots/879e58bdd9566632b27a8a81f0e2961873311f67...
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:46 [gpu_model_runner.py:2634] Loading model from scratch...
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:46 [cuda.py:372] Using FlexAttention backend on V1 engine.
# Loading safetensors checkpoint shards: 100% 1/1 [00:08<00:00,  8.26s/it]
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:55 [default_loader.py:267] Loading weights took 8.32 seconds
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:56 [gpu_model_runner.py:2653] Model loading took 2.1639 GiB and 8.661956 seconds
# (EngineCore_DP0 pid=6060) INFO 03-22 07:06:56 [gpu_model_runner.py:3344] Encoder cache will be initialized with a budget of 14175 tokens, and profiled with 1 video items of the maximum feature size.
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:20 [backends.py:548] Using cache directory: /root/.cache/vllm/torch_compile_cache/d288019e11/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:20 [backends.py:559] Dynamo bytecode transform time: 6.57 s
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:22 [backends.py:164] Directly load the compiled graph(s) for dynamic shape from the cache, took 2.190 s
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:23 [monitor.py:34] torch.compile takes 6.57 s in total
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:25 [gpu_worker.py:298] Available KV cache memory: 2.17 GiB
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:25 [kv_cache_utils.py:1087] GPU KV cache size: 190,000 tokens
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:25 [kv_cache_utils.py:1091] Maximum concurrency for 16,384 tokens per request: 11.60x
# (EngineCore_DP0 pid=6060) WARNING 03-22 07:07:25 [gpu_model_runner.py:3663] CUDAGraphMode.FULL_AND_PIECEWISE is not supported with FlexAttentionMetadataBuilder backend (support: AttentionCGSupport.NEVER); setting cudagraph_mode=PIECEWISE because attention is compiled piecewise
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100% 67/67 [00:03<00:00, 19.13it/s]
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:30 [gpu_model_runner.py:3480] Graph capturing finished in 5 secs, took 0.38 GiB
# (EngineCore_DP0 pid=6060) INFO 03-22 07:07:30 [core.py:210] init engine (profile, create kv cache, warmup model) took 34.20 seconds
# INFO 03-22 07:07:31 [llm.py:306] Supported_tasks: ['generate']
# 2026-03-22 07:07:31.634 | INFO     | mineru.backend.vlm.vlm_analyze:get_model:218 - get vllm-engine predictor cost: 81.67s
# 2026-03-22 07:07:35.905 | INFO     | mineru.backend.hybrid.hybrid_analyze:get_batch_ratio:365 - hybrid batch ratio (auto, vram=15GB): 4
# Adding requests: 100% 15/15 [00:04<00:00,  3.25it/s]
# Processed prompts: 100% 15/15 [01:36<00:00,  6.45s/it, est. speed input: 216.26 toks/s, output: 48.64 toks/s]
# Adding requests: 100% 12/12 [00:00<00:00, 66.90it/s]
# Processed prompts: 100% 12/12 [00:22<00:00,  1.87s/it, est. speed input: 127.78 toks/s, output: 89.29 toks/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 8035.07it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 8701.88it/s]
# Fetching 1 files: 100% 1/1 [00:00<00:00, 2916.76it/s]
# Fetching 7 files: 100% 7/7 [00:00<00:00, 10882.18it/s]
# MFD Predict: 100% 15/15 [00:05<00:00,  2.87it/s]
# MFR Predict: 100% 80/80 [00:07<00:00, 10.09it/s]
# OCR-det: 100% 15/15 [00:03<00:00,  4.81it/s]
# 2026-03-22 07:10:09.364 | INFO     | mineru.cli.common:_process_output:168 - local output dir is ./attention_is_all_you_need/hybrid_auto
# ERROR 03-22 07:10:12 [core_client.py:564] Engine core proc EngineCore_DP0 died unexpectedly, shutting down client.
